# %% [markdown]
# <a href="https://colab.research.google.com/github/lpgod/Crpt-DRL/blob/main/Crypto_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from transformers import BertTokenizer, BertModel
import random
from collections import deque
from dateutil import parser

df = pd.read_csv('/content/Binance_ETHUSDT_d.csv', skiprows=1)

column_names = ['UNIX', 'date', 'symbol', 'open', 'high', 'low', 'close', 'Volume ETH', 'Volume USDT', 'tradecount']
df.columns = column_names

df['date'] = pd.to_datetime(df['date'])

plt.figure(figsize=(14, 7))
plt.plot(df['date'], df['close'], label='Closing Price', color='blue')
plt.xlabel('Date')
plt.ylabel('Price (ETH)')
plt.title('ETH Closing Price Over Time')
plt.legend()
plt.grid(True)
plt.show()


def truncate_text(text, max_length=512):
    tokens = tokenizer.tokenize(text)
    if len(tokens) > max_length:
        tokens = tokens[:max_length]
    return tokenizer.convert_tokens_to_string(tokens)

def get_bert_vector(text):
    inputs = tokenizer(text, return_tensors='pt', truncation=True, max_length=512)
    inputs = inputs.to(device)
    with torch.no_grad():
        outputs = bert_model(**inputs)
    last_hidden_state = outputs.last_hidden_state
    pooled_output = torch.mean(last_hidden_state, dim=1)  # Example pooling strategy
    return pooled_output.squeeze().cpu().numpy()



class TradingEnv:
    def __init__(self, df, news_df):
        self.df = df
        self.news_df = news_df
        self.current_step = 0
        self.actions = ['buy', 'sell', 'hold']
        self.holding = False
        self.buy_price = 0.0
        self.balance = 10000
        self.stock_held = 0
        self.purchase_fee = 0.001
        self.sale_fee = 0.001

    def reset(self):
        self.current_step = 0
        self.holding = False
        self.buy_price = 0.0
        self.balance = 10000
        self.stock_held = 0
        return self.get_state()

    def step(self, action):
        if self.current_step >= len(self.df) - 1:
            done = True
            next_state = None
        else:
            self.current_step += 1
            done = False
            next_state = self.get_state()

        reward = self.calculate_reward(action)
        return next_state, reward, done

    def calculate_reward(self, action):
        current_price = self.df.iloc[self.current_step]['close']
        reward = 0
        if action == 'buy':
            if self.balance >= current_price * (1 + self.purchase_fee):
                self.stock_held += 1
                self.balance -= current_price * (1 + self.purchase_fee)
            else:
                reward = -1
        elif action == 'sell':
            if self.stock_held > 0:
                self.stock_held -= 1
                self.balance += current_price * (1 - self.sale_fee)
                reward = current_price - self.buy_price
            else:
                reward = -1
        elif action == 'hold':
            if self.holding:
                if current_price > self.buy_price:
                    reward = current_price - self.buy_price
                else:
                    reward = current_price - self.buy_price
                    if reward < 0:
                        reward *= 2

        return reward

    def get_state(self):
        price_data = self.df.iloc[self.current_step].to_dict()
        news_data = self.get_news(self.df.iloc[self.current_step]['date'])
        state_text = " ".join([f"{k}: {v}" for k, v in price_data.items()]) + " " + news_data

        # Truncate to 512 tokens
        encoded_input = tokenizer.encode(state_text, add_special_tokens=True, max_length=512, truncation=True)
        state_text_truncated = tokenizer.convert_tokens_to_string(tokenizer.convert_ids_to_tokens(encoded_input))

        return state_text_truncated


    def get_news(self, date):
        news_on_date = self.news_df[self.news_df['date'].dt.date == date.date()]
        news_texts = news_on_date['text'].tolist()
        combined_news = " ".join(news_texts)
        return combined_news

# Load price data
df = pd.read_csv('/content/Binance_ETHUSDT_d.csv', skiprows=1)
column_names = ['UNIX', 'date', 'symbol', 'open', 'high', 'low', 'close', 'Volume ETH', 'Volume USDT', 'tradecount']
df.columns = column_names
df['date'] = pd.to_datetime(df['date'])

numeric_columns = ['open', 'high', 'low', 'close', 'Volume ETH', 'Volume USDT']
df[numeric_columns] = df[numeric_columns].apply(pd.to_numeric, errors='coerce')
df[numeric_columns] = df[numeric_columns] / df[numeric_columns].max()

# Load news data
news_df = pd.read_csv('/content/news.csv')
news_df['date'] = news_df['date'].apply(parser.parse)

env = TradingEnv(df, news_df)

class DQN(nn.Module):
    def __init__(self, state_dim, action_dim):
        super(DQN, self).__init__()
        self.fc1 = nn.Linear(state_dim, 128)
        self.fc2 = nn.Linear(128, action_dim)

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        return self.fc2(x)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

state_dim = 768  # Assuming BERT embedding size
action_dim = len(env.actions)

dqn = DQN(state_dim, action_dim).to(device)
optimizer = optim.Adam(dqn.parameters())

tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
bert_model = BertModel.from_pretrained('bert-base-uncased').to(device)

memory_size = 100
replay_memory = deque(maxlen=memory_size)
batch_size = 64

# params
alpha = 0.01
gamma = 0.95  #discount factor
epsilon = 1.0  #exploration rate
epsilon_decay = 0.9  #decay for exploration rate
min_epsilon = 0.05  #minimum exploration rate

num_episodes = 100

def get_lowest_price(window):
    return window['low'].min()

final_balances = []  #array to store final balances of each episode

for episode in range(num_episodes):
    state_text = env.reset()
    state_vector = get_bert_vector(state_text)
    done = False
    total_reward = 0
    episode_losses = []
    episode_action_counts = {'buy': 0, 'sell': 0, 'hold': 0}

    while not done:
        state_tensor = torch.tensor(state_vector, dtype=torch.float32).unsqueeze(0).to(device)
        q_values = dqn(state_tensor)

        if random.uniform(0, 1) < epsilon:
            action = random.choice(range(action_dim))
        else:
            action = torch.argmax(q_values).item()

        next_state_text, reward, done = env.step(env.actions[action])
        episode_action_counts[env.actions[action]] += 1

        if next_state_text is not None:
            next_state_vector = get_bert_vector(next_state_text)
        else:
            next_state_vector = state_vector

        replay_memory.append((state_vector, action, reward, next_state_vector, done))

        if len(replay_memory) >= batch_size:
            batch = random.sample(replay_memory, batch_size)
            state_batch, action_batch, reward_batch, next_state_batch, done_batch = zip(*batch)

            state_batch_tensor = torch.tensor(np.array(state_batch), dtype=torch.float32).to(device)
            action_batch_tensor = torch.tensor(action_batch, dtype=torch.long).to(device)
            reward_batch_tensor = torch.tensor(reward_batch, dtype=torch.float32).to(device)
            next_state_batch_tensor = torch.tensor(np.array(next_state_batch), dtype=torch.float32).to(device)
            done_batch_tensor = torch.tensor(done_batch, dtype=torch.float32).to(device)

            q_values_batch = dqn(state_batch_tensor)
            next_q_values_batch = dqn(next_state_batch_tensor)

            target_batch = reward_batch_tensor + gamma * torch.max(next_q_values_batch, dim=1)[0] * (1 - done_batch_tensor)
            current_q_values = q_values_batch.gather(1, action_batch_tensor.unsqueeze(1)).squeeze(1)

            loss = nn.functional.mse_loss(current_q_values, target_batch)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            episode_losses.append(loss.item())

        state_vector = next_state_vector
        total_reward += reward

        if env.current_step % 5 == 0:
            recent_window = df.iloc[max(0, env.current_step-5):env.current_step+1]
            lowest_price = get_lowest_price(recent_window)
            if df.iloc[env.current_step]['low'] < lowest_price and env.actions[action] == 'buy':
                total_reward -= 1  # Penalize if a new lowest price is detected and agent buys at this price

    avg_loss = sum(episode_losses) / len(episode_losses) if episode_losses else 0
    final_balance = env.balance + env.stock_held * df.iloc[-1]['close']
    final_balances.append(final_balance)
    print(f'Episode {episode + 1}, Total Reward: {total_reward:.2f}, Avg Loss: {avg_loss:.4f}')
    print(f'Actions taken: {episode_action_counts}')
    print(f'Final Balance: {final_balance:.2f}\n')
    print(f'epsilon: {epsilon}')
    print("--------------------------------------")
    if epsilon > min_epsilon:
        epsilon = epsilon * epsilon_decay


plt.plot(final_balances)
plt.xlabel('Episode')
plt.ylabel('Final Balance')
plt.title('Final Balance per Episode')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Episode 1, Total Reward: 201.35, Avg Loss: 0.0189
# Actions taken: {'buy': 828, 'sell': 824, 'hold': 835}
# Final Balance: 9996.88
#
# epsilon: 1.0
# --------------------------------------
# Episode 2, Total Reward: 44.10, Avg Loss: 0.0959
# Actions taken: {'buy': 764, 'sell': 916, 'hold': 807}
# Final Balance: 10001.72
#
# epsilon: 0.9
# --------------------------------------
# Episode 3, Total Reward: 34.53, Avg Loss: 0.1110
# Actions taken: {'buy': 791, 'sell': 943, 'hold': 753}
# Final Balance: 10005.78
#
# epsilon: 0.81
# --------------------------------------
# Episode 4, Total Reward: -24.79, Avg Loss: 0.1289
# Actions taken: {'buy': 721, 'sell': 948, 'hold': 818}
# Final Balance: 9994.18
#
# epsilon: 0.7290000000000001
# --------------------------------------
# Episode 5, Total Reward: -79.86, Avg Loss: 0.1357
# Actions taken: {'buy': 693, 'sell': 926, 'hold': 868}
# Final Balance: 9985.94
#
# epsilon: 0.6561000000000001
# --------------------------------------
# Episode 6, Total Reward: -66.07, Avg Loss: 0.1217
# Actions taken: {'buy': 749, 'sell': 986, 'hold': 752}
# Final Balance: 9995.21
#
# epsilon: 0.5904900000000002
# --------------------------------------
# Episode 7, Total Reward: -77.59, Avg Loss: 0.1186
# Actions taken: {'buy': 666, 'sell': 880, 'hold': 941}
# Final Balance: 9987.45
#
# epsilon: 0.5314410000000002
# --------------------------------------
# Episode 8, Total Reward: -73.46, Avg Loss: 0.1275
# Actions taken: {'buy': 747, 'sell': 865, 'hold': 875}
# Final Balance: 9985.74
#
# epsilon: 0.47829690000000014
# --------------------------------------
# Episode 9, Total Reward: -50.15, Avg Loss: 0.1143
# Actions taken: {'buy': 626, 'sell': 849, 'hold': 1012}
# Final Balance: 9989.94
#
# epsilon: 0.43046721000000016
# --------------------------------------
# Episode 10, Total Reward: -7.06, Avg Loss: 0.1044
# Actions taken: {'buy': 956, 'sell': 894, 'hold': 637}
# Final Balance: 9971.07
#
# epsilon: 0.38742048900000015
# --------------------------------------
# Episode 11, Total Reward: -68.77, Avg Loss: 0.1069
# Actions taken: {'buy': 591, 'sell': 731, 'hold': 1165}
# Final Balance: 9966.79
#
# epsilon: 0.34867844010000015
# --------------------------------------
# Episode 12, Total Reward: -115.19, Avg Loss: 0.0838
# Actions taken: {'buy': 338, 'sell': 503, 'hold': 1646}
# Final Balance: 9990.63
#
# epsilon: 0.31381059609000017
# --------------------------------------
# Episode 13, Total Reward: -43.72, Avg Loss: 0.0852
# Actions taken: {'buy': 752, 'sell': 648, 'hold': 1087}
# Final Balance: 9977.59
#
# epsilon: 0.28242953648100017
# --------------------------------------
# Episode 14, Total Reward: 25.07, Avg Loss: 0.0900
# Actions taken: {'buy': 730, 'sell': 890, 'hold': 867}
# Final Balance: 9992.78
#
# epsilon: 0.25418658283290013
# --------------------------------------
# Episode 15, Total Reward: -6.74, Avg Loss: 0.0758
# Actions taken: {'buy': 678, 'sell': 845, 'hold': 964}
# Final Balance: 9962.61
#
# epsilon: 0.22876792454961012
# --------------------------------------
# Episode 16, Total Reward: 150.49, Avg Loss: 0.1309
# Actions taken: {'buy': 776, 'sell': 724, 'hold': 987}
# Final Balance: 10051.15
#
# epsilon: 0.2058911320946491
# --------------------------------------
# Episode 17, Total Reward: -102.54, Avg Loss: 0.0659
# Actions taken: {'buy': 273, 'sell': 408, 'hold': 1806}
# Final Balance: 9962.75
#
# epsilon: 0.1853020188851842
# --------------------------------------
# Episode 18, Total Reward: -9.67, Avg Loss: 0.1004
# Actions taken: {'buy': 593, 'sell': 755, 'hold': 1139}
# Final Balance: 9935.09
#
# epsilon: 0.16677181699666577
# --------------------------------------
# Episode 19, Total Reward: -3.27, Avg Loss: 0.1029
# Actions taken: {'buy': 1370, 'sell': 426, 'hold': 691}
# Final Balance: 10031.88
#
# epsilon: 0.1500946352969992
# --------------------------------------
# Episode 20, Total Reward: 7.98, Avg Loss: 0.0547
# Actions taken: {'buy': 643, 'sell': 542, 'hold': 1302}
# Final Balance: 9971.63
#
# epsilon: 0.13508517176729928
# --------------------------------------
# Episode 21, Total Reward: 10.67, Avg Loss: 0.0749
# Actions taken: {'buy': 879, 'sell': 1013, 'hold': 595}
# Final Balance: 9781.57
#
# epsilon: 0.12157665459056936
# --------------------------------------
# Episode 22, Total Reward: -41.19, Avg Loss: 0.0719
# Actions taken: {'buy': 1289, 'sell': 345, 'hold': 853}
# Final Balance: 10010.56
#
# epsilon: 0.10941898913151243
# --------------------------------------
# Episode 23, Total Reward: 113.00, Avg Loss: 0.1232
# Actions taken: {'buy': 563, 'sell': 718, 'hold': 1206}
# Final Balance: 10042.27
#
# epsilon: 0.0984770902183612
# --------------------------------------
# Episode 24, Total Reward: -45.31, Avg Loss: 0.0581
# Actions taken: {'buy': 1148, 'sell': 300, 'hold': 1039}
# Final Balance: 10002.20
#
# epsilon: 0.08862938119652508
# --------------------------------------
# Episode 25, Total Reward: -14.89, Avg Loss: 0.0890
# Actions taken: {'buy': 454, 'sell': 575, 'hold': 1458}
# Final Balance: 9971.03
#
# epsilon: 0.07976644307687257
# --------------------------------------
# Episode 26, Total Reward: -35.31, Avg Loss: 0.0659
# Actions taken: {'buy': 1606, 'sell': 341, 'hold': 540}
# Final Balance: 9899.68
#
# epsilon: 0.07178979876918531
# --------------------------------------
# Episode 27, Total Reward: 9.50, Avg Loss: 0.0726
# Actions taken: {'buy': 448, 'sell': 525, 'hold': 1514}
# Final Balance: 9957.42
#
# epsilon: 0.06461081889226679
# --------------------------------------
# Episode 28, Total Reward: -38.75, Avg Loss: 0.0635
# Actions taken: {'buy': 1680, 'sell': 358, 'hold': 449}
# Final Balance: 9862.93
#
# epsilon: 0.05814973700304011
# --------------------------------------
# Episode 29, Total Reward: 126.89, Avg Loss: 0.1168
# Actions taken: {'buy': 626, 'sell': 771, 'hold': 1090}
# Final Balance: 10018.68
#
# epsilon: 0.0523347633027361
# --------------------------------------
# Episode 30, Total Reward: -8.25, Avg Loss: 0.0084
# Actions taken: {'buy': 320, 'sell': 50, 'hold': 2117}
# Final Balance: 9998.70
#
# epsilon: 0.04710128697246249
# --------------------------------------
# Episode 31, Total Reward: -63.62, Avg Loss: 0.0346
# Actions taken: {'buy': 184, 'sell': 135, 'hold': 2168}
# Final Balance: 9987.19
#
# epsilon: 0.04710128697246249
# --------------------------------------
# Episode 32, Total Reward: -28.50, Avg Loss: 0.0637
# Actions taken: {'buy': 1402, 'sell': 263, 'hold': 822}
# Final Balance: 9999.46
#
# epsilon: 0.04710128697246249
# --------------------------------------
# Episode 33, Total Reward: 73.38, Avg Loss: 0.0470
# Actions taken: {'buy': 858, 'sell': 925, 'hold': 704}
# Final Balance: 9746.94
#
# epsilon: 0.04710128697246249
# --------------------------------------
# Episode 34, Total Reward: -47.07, Avg Loss: 0.0262
# Actions taken: {'buy': 734, 'sell': 256, 'hold': 1497}
# Final Balance: 9917.87
#
# epsilon: 0.04710128697246249
# --------------------------------------
# Episode 35, Total Reward: 21.41, Avg Loss: 0.0321
# Actions taken: {'buy': 965, 'sell': 1031, 'hold': 491}
# Final Balance: 9627.62
#
# epsilon: 0.04710128697246249
# --------------------------------------
# Episode 36, Total Reward: 3.34, Avg Loss: 0.0067
# Actions taken: {'buy': 317, 'sell': 36, 'hold': 2134}
# Final Balance: 9990.37
#
# epsilon: 0.04710128697246249
# --------------------------------------
# Episode 37, Total Reward: -45.51, Avg Loss: 0.0327
# Actions taken: {'buy': 1769, 'sell': 215, 'hold': 503}
# Final Balance: 9718.94
#
# epsilon: 0.04710128697246249
# --------------------------------------
# Episode 38, Total Reward: 106.94, Avg Loss: 0.1464
# Actions taken: {'buy': 549, 'sell': 740, 'hold': 1198}
# Final Balance: 10087.66
#
# epsilon: 0.04710128697246249
# --------------------------------------
# Episode 39, Total Reward: -1.96, Avg Loss: 0.0058
# Actions taken: {'buy': 274, 'sell': 38, 'hold': 2175}
# Final Balance: 9936.58
#
# epsilon: 0.04710128697246249
# --------------------------------------
# Episode 40, Total Reward: -37.97, Avg Loss: 0.0372
# Actions taken: {'buy': 1994, 'sell': 215, 'hold': 278}
# Final Balance: 9630.88
#
# epsilon: 0.04710128697246249
# --------------------------------------
# Episode 41, Total Reward: -57.43, Avg Loss: 0.0485
# Actions taken: {'buy': 153, 'sell': 256, 'hold': 2078}
# Final Balance: 9972.77
#
# epsilon: 0.04710128697246249
# --------------------------------------
# Episode 42, Total Reward: -24.67, Avg Loss: 0.0437
# Actions taken: {'buy': 1255, 'sell': 440, 'hold': 792}
# Final Balance: 9914.95
#
# epsilon: 0.04710128697246249
# --------------------------------------
# Episode 43, Total Reward: 62.18, Avg Loss: 0.0053
# Actions taken: {'buy': 1624, 'sell': 717, 'hold': 146}
# Final Balance: 9554.68
#
# epsilon: 0.04710128697246249
# --------------------------------------
# Episode 44, Total Reward: -58.99, Avg Loss: 0.0257
# Actions taken: {'buy': 379, 'sell': 107, 'hold': 2001}
# Final Balance: 9995.59
#
# epsilon: 0.04710128697246249
# --------------------------------------
# Episode 45, Total Reward: -41.30, Avg Loss: 0.0209
# Actions taken: {'buy': 525, 'sell': 446, 'hold': 1516}
# Final Balance: 9979.33
#
# epsilon: 0.04710128697246249
# --------------------------------------
# Episode 46, Total Reward: 17.64, Avg Loss: 0.0083
# Actions taken: {'buy': 2091, 'sell': 100, 'hold': 296}
# Final Balance: 9562.98
#
# epsilon: 0.04710128697246249
# --------------------------------------
# Episode 47, Total Reward: -40.56, Avg Loss: 0.0190
# Actions taken: {'buy': 2060, 'sell': 79, 'hold': 348}
# Final Balance: 9587.39
#
# epsilon: 0.04710128697246249
# --------------------------------------
# Episode 48, Total Reward: -40.00, Avg Loss: 0.0443
# Actions taken: {'buy': 308, 'sell': 221, 'hold': 1958}
# Final Balance: 9981.05
#
# epsilon: 0.04710128697246249
# --------------------------------------
# Episode 49, Total Reward: -35.24, Avg Loss: 0.0609
# Actions taken: {'buy': 1570, 'sell': 271, 'hold': 646}
# Final Balance: 9916.67
#
# epsilon: 0.04710128697246249
# --------------------------------------
# Episode 50, Total Reward: -7.22, Avg Loss: 0.0227
# Actions taken: {'buy': 854, 'sell': 919, 'hold': 714}
# Final Balance: 9643.16
#
# epsilon: 0.04710128697246249
# --------------------------------------
# Episode 51, Total Reward: 7.51, Avg Loss: 0.0059
# Actions taken: {'buy': 486, 'sell': 30, 'hold': 1971}
# Final Balance: 9970.40
#
# epsilon: 0.04710128697246249
# --------------------------------------
# Episode 52, Total Reward: -30.11, Avg Loss: 0.0237
# Actions taken: {'buy': 1639, 'sell': 152, 'hold': 696}
# Final Balance: 9739.63
#
# epsilon: 0.04710128697246249
# --------------------------------------
# Episode 53, Total Reward: -36.02, Avg Loss: 0.0511
# Actions taken: {'buy': 1923, 'sell': 311, 'hold': 253}
# Final Balance: 9672.62
#
# epsilon: 0.04710128697246249
# --------------------------------------
# Episode 54, Total Reward: -12.41, Avg Loss: 0.0535
# Actions taken: {'buy': 340, 'sell': 451, 'hold': 1696}
# Final Balance: 9942.69
#
# epsilon: 0.04710128697246249
# --------------------------------------
# Episode 55, Total Reward: 13.48, Avg Loss: 0.0487
# Actions taken: {'buy': 1293, 'sell': 457, 'hold': 737}
# Final Balance: 9961.58
#
# epsilon: 0.04710128697246249
# --------------------------------------
# Episode 56, Total Reward: -12.67, Avg Loss: 0.0274
# Actions taken: {'buy': 979, 'sell': 1061, 'hold': 447}
# Final Balance: 9662.14
#
# epsilon: 0.04710128697246249
# --------------------------------------
# Episode 57, Total Reward: -1.57, Avg Loss: 0.0090
# Actions taken: {'buy': 242, 'sell': 42, 'hold': 2203}
# Final Balance: 9998.31
#
# epsilon: 0.04710128697246249
# --------------------------------------
# Episode 58, Total Reward: -37.47, Avg Loss: 0.0366
# Actions taken: {'buy': 1753, 'sell': 238, 'hold': 496}
# Final Balance: 9710.91
#
# epsilon: 0.04710128697246249
# --------------------------------------
# Episode 59, Total Reward: -11.27, Avg Loss: 0.1392
# Actions taken: {'buy': 436, 'sell': 669, 'hold': 1382}
# Final Balance: 10039.31
#
# epsilon: 0.04710128697246249
# --------------------------------------
# Episode 60, Total Reward: 14.31, Avg Loss: 0.0041
# Actions taken: {'buy': 444, 'sell': 123, 'hold': 1920}
# Final Balance: 9896.36
#
# epsilon: 0.04710128697246249
# --------------------------------------
# Episode 61, Total Reward: 8.73, Avg Loss: 0.0202
# Actions taken: {'buy': 1689, 'sell': 501, 'hold': 297}
# Final Balance: 9644.33
#
# epsilon: 0.04710128697246249
# --------------------------------------
# Episode 62, Total Reward: -64.37, Avg Loss: 0.0260
# Actions taken: {'buy': 507, 'sell': 103, 'hold': 1877}
# Final Balance: 9994.74
#
# epsilon: 0.04710128697246249
# --------------------------------------
# Episode 63, Total Reward: -40.51, Avg Loss: 0.0229
# Actions taken: {'buy': 190, 'sell': 133, 'hold': 2164}
# Final Balance: 9996.11
#
# epsilon: 0.04710128697246249
# --------------------------------------
# Episode 64, Total Reward: -35.58, Avg Loss: 0.0282
# Actions taken: {'buy': 1793, 'sell': 164, 'hold': 530}
# Final Balance: 9686.77
#
# epsilon: 0.04710128697246249
# --------------------------------------
# Episode 65, Total Reward: -35.70, Avg Loss: 0.0497
# Actions taken: {'buy': 1911, 'sell': 311, 'hold': 265}
# Final Balance: 9704.91
#
# epsilon: 0.04710128697246249
# --------------------------------------
# Episode 66, Total Reward: 137.14, Avg Loss: 0.0611
# Actions taken: {'buy': 797, 'sell': 853, 'hold': 837}
# Final Balance: 9843.45
#
# epsilon: 0.04710128697246249
# --------------------------------------
# Episode 67, Total Reward: 5.30, Avg Loss: 0.0036
# Actions taken: {'buy': 498, 'sell': 33, 'hold': 1956}
# Final Balance: 9943.91
#
# epsilon: 0.04710128697246249
# --------------------------------------
# Episode 68, Total Reward: -41.73, Avg Loss: 0.0274
# Actions taken: {'buy': 247, 'sell': 121, 'hold': 2119}
# Final Balance: 9993.39
#
# epsilon: 0.04710128697246249
# --------------------------------------
# Episode 69, Total Reward: -39.26, Avg Loss: 0.0280
# Actions taken: {'buy': 2048, 'sell': 143, 'hold': 296}
# Final Balance: 9621.28
#
# epsilon: 0.04710128697246249
# --------------------------------------
# Episode 70, Total Reward: -45.26, Avg Loss: 0.0432
# Actions taken: {'buy': 290, 'sell': 265, 'hold': 1932}
# Final Balance: 9954.54
#
# epsilon: 0.04710128697246249
# --------------------------------------
# Episode 71, Total Reward: 30.38, Avg Loss: 0.1017
# Actions taken: {'buy': 1486, 'sell': 422, 'hold': 579}
# Final Balance: 10036.35
#
# epsilon: 0.04710128697246249
# --------------------------------------
# Episode 72, Total Reward: 20.57, Avg Loss: 0.0243
# Actions taken: {'buy': 873, 'sell': 932, 'hold': 682}
# Final Balance: 9657.96
#
# epsilon: 0.04710128697246249
# --------------------------------------
# Episode 73, Total Reward: 25.42, Avg Loss: 0.0059
# Actions taken: {'buy': 614, 'sell': 218, 'hold': 1655}
# Final Balance: 9897.88
#
# epsilon: 0.04710128697246249
# --------------------------------------
# Episode 74, Total Reward: -42.16, Avg Loss: 0.0219
# Actions taken: {'buy': 2004, 'sell': 177, 'hold': 306}
# Final Balance: 9530.06
#
# epsilon: 0.04710128697246249
# --------------------------------------
# Episode 75, Total Reward: -46.86, Avg Loss: 0.0198
# Actions taken: {'buy': 563, 'sell': 100, 'hold': 1824}
# Final Balance: 9986.42
#
# epsilon: 0.04710128697246249
# --------------------------------------
# Episode 76, Total Reward: -50.26, Avg Loss: 0.0248
# Actions taken: {'buy': 279, 'sell': 114, 'hold': 2094}
# Final Balance: 9994.61
#
# epsilon: 0.04710128697246249
# --------------------------------------
# Episode 77, Total Reward: -9.27, Avg Loss: 0.0787
# Actions taken: {'buy': 1442, 'sell': 288, 'hold': 757}
# Final Balance: 10016.86
#
# epsilon: 0.04710128697246249
# --------------------------------------
# Episode 78, Total Reward: 144.33, Avg Loss: 0.1309
# Actions taken: {'buy': 551, 'sell': 699, 'hold': 1237}
# Final Balance: 10072.56
#
# epsilon: 0.04710128697246249
# --------------------------------------
# Episode 79, Total Reward: -43.01, Avg Loss: 0.0226
# Actions taken: {'buy': 379, 'sell': 444, 'hold': 1664}
# Final Balance: 9933.77
#
# epsilon: 0.04710128697246249
# --------------------------------------
# Episode 80, Total Reward: 5.81, Avg Loss: 0.0045
# Actions taken: {'buy': 506, 'sell': 31, 'hold': 1950}
# Final Balance: 9924.30
#
# epsilon: 0.04710128697246249
# --------------------------------------
# Episode 81, Total Reward: -46.13, Avg Loss: 0.0360
# Actions taken: {'buy': 210, 'sell': 196, 'hold': 2081}
# Final Balance: 9970.29
#
# epsilon: 0.04710128697246249
# --------------------------------------
# Episode 82, Total Reward: -56.01, Avg Loss: 0.0245
# Actions taken: {'buy': 42, 'sell': 110, 'hold': 2335}
# Final Balance: 9998.97
#
# epsilon: 0.04710128697246249
# --------------------------------------
# Episode 83, Total Reward: -29.33, Avg Loss: 0.0388
# Actions taken: {'buy': 1255, 'sell': 216, 'hold': 1016}
# Final Balance: 9996.69
#
# epsilon: 0.04710128697246249
# --------------------------------------
# Episode 84, Total Reward: 56.56, Avg Loss: 0.0353
# Actions taken: {'buy': 791, 'sell': 847, 'hold': 849}
# Final Balance: 9724.80
#
# epsilon: 0.04710128697246249
# --------------------------------------
# Episode 85, Total Reward: 6.35, Avg Loss: 0.0047
# Actions taken: {'buy': 473, 'sell': 26, 'hold': 1988}
# Final Balance: 9981.13
#
# epsilon: 0.04710128697246249
# --------------------------------------
# Episode 86, Total Reward: -31.43, Avg Loss: 0.0178
# Actions taken: {'buy': 1605, 'sell': 94, 'hold': 788}
# Final Balance: 9657.65
#
# epsilon: 0.04710128697246249
# --------------------------------------
# Episode 87, Total Reward: -50.68, Avg Loss: 0.0407
# Actions taken: {'buy': 133, 'sell': 156, 'hold': 2198}
# Final Balance: 9997.76
#
# epsilon: 0.04710128697246249
# --------------------------------------
# Episode 88, Total Reward: 77.88, Avg Loss: 0.0865
# Actions taken: {'buy': 1437, 'sell': 441, 'hold': 609}
# Final Balance: 10053.25
#
# epsilon: 0.04710128697246249
# --------------------------------------
# Episode 89, Total Reward: 116.80, Avg Loss: 0.0641
# Actions taken: {'buy': 841, 'sell': 920, 'hold': 726}
# Final Balance: 9814.82
#
# epsilon: 0.04710128697246249
# --------------------------------------
# Episode 90, Total Reward: 48.06, Avg Loss: 0.0069
# Actions taken: {'buy': 390, 'sell': 358, 'hold': 1739}
# Final Balance: 9940.58
#
# epsilon: 0.04710128697246249
# --------------------------------------
# Episode 91, Total Reward: -65.20, Avg Loss: 0.0305
# Actions taken: {'buy': 2085, 'sell': 121, 'hold': 281}
# Final Balance: 9561.62
#
# epsilon: 0.04710128697246249
# --------------------------------------
# Episode 92, Total Reward: -48.55, Avg Loss: 0.0525
# Actions taken: {'buy': 197, 'sell': 317, 'hold': 1973}
# Final Balance: 9971.72
#
# epsilon: 0.04710128697246249
# --------------------------------------
# Episode 93, Total Reward: -23.98, Avg Loss: 0.0783
# Actions taken: {'buy': 348, 'sell': 491, 'hold': 1648}
# Final Balance: 9950.77
#
# epsilon: 0.04710128697246249
# --------------------------------------
# Episode 94, Total Reward: 1.83, Avg Loss: 0.0066
# Actions taken: {'buy': 351, 'sell': 43, 'hold': 2093}
# Final Balance: 9915.63
#
# epsilon: 0.04710128697246249
# --------------------------------------
# Episode 95, Total Reward: -32.69, Avg Loss: 0.0161
# Actions taken: {'buy': 2003, 'sell': 76, 'hold': 408}
# Final Balance: 9547.00
#
# epsilon: 0.04710128697246249
# --------------------------------------
# Episode 96, Total Reward: -42.51, Avg Loss: 0.0364
# Actions taken: {'buy': 225, 'sell': 224, 'hold': 2038}
# Final Balance: 9993.17
#
# epsilon: 0.04710128697246249
# --------------------------------------
# Episode 97, Total Reward: -51.04, Avg Loss: 0.0551
# Actions taken: {'buy': 132, 'sell': 193, 'hold': 2162}
# Final Balance: 10026.54
#
# epsilon: 0.04710128697246249
# --------------------------------------
# Episode 98, Total Reward: -29.64, Avg Loss: 0.0620
# Actions taken: {'buy': 1357, 'sell': 280, 'hold': 850}
# Final Balance: 10006.72
#
# epsilon: 0.04710128697246249
# --------------------------------------
# Episode 99, Total Reward: 41.52, Avg Loss: 0.0350
# Actions taken: {'buy': 868, 'sell': 928, 'hold': 691}
# Final Balance: 9686.58
#
# epsilon: 0.04710128697246249
# --------------------------------------
# Episode 100, Total Reward: 3.42, Avg Loss: 0.0076
# Actions taken: {'buy': 502, 'sell': 39, 'hold': 1946}
# Final Balance: 9958.80
#
# epsilon: 0.04710128697246249
# --------------------------------------
